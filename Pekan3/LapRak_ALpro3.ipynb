# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **ALGORITMA & PEMOGRAMAN**
#
# **“OPERATOR PADA PYTHON”**
#
# **Disusun Oleh :**
#
# **Muhammad Farhan Amri**
#
# **2611533010**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Sherly Sukmadira**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkat-Nya, sehingga penulis dapat menyelesaikan laporan praktikum ini yang telah dilaksanakan sebagai pertemuan ke-3 untuk mata kuliah Praktikum Algoritma dan Pemrograman. Praktikum ini berfokus pada pembahasan dan penerapan berbagai operasi dasar menggunakan bahasa Python.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep operator aritmatika, perbandingan, logika, penugasan, keanggotaan, identitas, serta bitwise pada proyek nyata.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, September 2026

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Python menyediakan berbagai jenis operator yang berfungsi untuk memanipulasi nilai atau variabel. Pemahaman yang mendalam tentang jenis dan penggunaan operator sangat penting dalam pemrograman untuk menyelesaikan suatu masalah matematis dan logis secara komputasional. Pada praktikum ini, dipelajari berbagai macam jenis operator yang dapat diimplementasikan dalam struktur logika bahasa pemrograman Python.
#
# ## 1.2 Tujuan
# 1. Memahami jenis-jenis dan fungsi operator pada bahasa pemrograman Python.
# 2. Mengimplementasikan operator aritmatika, perbandingan, logika, penugasan (assignment), bitwise, dan operator lainnya ke dalam kode program.
# 3. Menganalisis alur dan hasil keluaran (output) dari setiap ekspresi yang menggunakan operator pada Python.
#
# ## 1.3 Manfaat
# 1. Menambah pemahaman mendalam mengenai pengolahan data menggunakan berbagai jenis operator.
# 2. Mampu menerapkan kombinasi operator untuk menyelesaikan permasalahan komputasi secara efektif dan efisien..

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# Berdasarkan modul praktikum, operator pada Python digunakan untuk melakukan operasi pada variabel dan nilai. Terdapat berbagai jenis operator yang digunakan, antara lain:
# 1. **Operator Aritmatika**: Digunakan untuk operasi matematika. Contohnya meliputi penjumlahan (+), pengurangan (-), perkalian (*), pembagian (/), pembagian bulat (//), modulus atau sisa bagi (%), dan pangkat (**).
# 2. **Operator Perbandingan (Comparison)**: Digunakan untuk membandingkan dua nilai dan menghasilkan nilai *boolean* True atau False. Operator yang tersedia adalah sama dengan (==), tidak sama dengan (!=), lebih besar (>), lebih kecil (<), lebih besar atau sama dengan (>=), dan lebih kecil atau sama dengan (<=).
# 3. **Operator Logika**: Digunakan untuk menggabungkan kondisi, meliputi `and` (bernilai True jika semua kondisi True), `or` (bernilai True jika salah satu kondisi True), dan `not` (membalik nilai logika).
# 4. **Operator Penugasan (Assignment)**: Digunakan untuk memberikan nilai ke suatu variabel. Contoh dari implementasinya yaitu `=`, `+=`, `-=`, `*=`, `/=`, `%=`, dan `**=`.
# 5. **Operator Keanggotaan (Membership)**: Digunakan untuk memeriksa apakah suatu nilai ada dalam suatu koleksi data, dengan memanfaatkan instruksi `in` dan `not in`.
# 6. **Operator Identitas (Identity)**: Digunakan untuk membandingkan lokasi objek di dalam memori. Operator `is` membandingkan kesamaan objek secara utuh, sedangkan `is not` menyatakan objek yang berbeda. Operator identitas berbeda dengan `==` yang hanya membandingkan isi/nilai suatu objek.
# 7. **Operator Bitwise**: Bekerja pada perhitungan *level bit* biner. Contoh operasi yang dapat dilakukan adalah AND (&), OR (|), XOR (^), NOT (~), geser kiri (<<), dan geser kanan (>>).

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program Aritmatika "aritmatika_2611533010.py"

# %%
# Buat file dengan nama aritmatika_2611533010.py
# Buat program untuk operator aritmatika dalam python
# Nama variabel ditambah 4 digit NIM terakhir contoh: angka1_3010
# Program ini menggunakan fungsi input()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer

angka1_3010 = int(input("Input angka-1: "))
angka2_3010 = int(input("Input angka-2: "))

# Penjumlahan
hasil_3010 = angka1_3010 + angka2_3010
print("\nOperator Penjumlahan")
print("Hasil =", hasil_3010)

# Pengurangan
hasil_3010 = angka1_3010 - angka2_3010
print("\nOperator Pengurangan")
print("Hasil =", hasil_3010)

# Perkalian
hasil_3010 = angka1_3010 * angka2_3010
print("\nOperator Perkalian")
print("Hasil =", hasil_3010)

# Pembagian, pembagian bulat, dan sisa bagi
if angka2_3010 !=0:
    hasil_3010 = angka1_3010 / angka2_3010
    print("\nOperator Pembagian")
    print("Hasil =", hasil_3010)

    hasil_3010 = angka1_3010 // angka2_3010
    print("\nOperator Pembagian Bulat")
    print("Hasil =", hasil_3010)

    hasil_3010 = angka1_3010 % angka2_3010
    print("\nOperator Sisa Bagi")
    print("Hasil =", hasil_3010)
else:
    print("Angka kedua tidak boleh bernilai 0.")

# Pangkat
hasil_3010 = angka1_3010 ** angka2_3010
print("\nOperator Pangkat")
print("Hasil =", hasil_3010)

# %% [markdown]
# **Penjelasan :**
# Program di atas menerapkan pengoperasian matematis dasar dengan menerima dua input nilai dari pengguna yang langsung dikonversikan ke integer menggunakan fungsi `int(input())`. Khusus untuk pengoperasian pembagian, terdapat pengamanan selektif `if-else` agar program tidak mengalami pesan error, yang mewajibkan variabel pembagi angka2_3010 tidak bernilai 0.

# %% [markdown]
# ### 2.2.2 Program Assignment "assignment_2611533010"

# %%
# Buat file dengan nama assignment_2611533010.py
# Nama variabel ditambah 4 digit NIM terakhir contoh: angka1_3010
# Program ini menggunakan fungsi input()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
# Program operator assignment dalam python

angka1_3010 = int(input("Input angka-1: "))
angka2_3010 = int(input("Input angka-2: "))

print("\nNilai awal angka1 =", angka1_3010)
print("\nNilai angka2 =", angka2_3010)

# Assignmant biasa
hasil_3010 = angka1_3010
print("\nAssignment biasa (=)")
print("Hasil =", hasil_3010)

# Assignment penambahan
hasil_3010 = angka1_3010
hasil_3010 += angka2_3010
print("\nAssignment penambahan (+=)")
print("Hasil =", hasil_3010)

# Assignment pengurangan
hasil_3010 = angka1_3010
hasil_3010 -= angka2_3010
print("\nAssignment pengurangan (-=)")
print("Hasil =", hasil_3010)

# Assignment perkalian
hasil_3010 = angka1_3010
hasil_3010 *= angka2_3010
print("\nAssignment perkalian (*=)")
print("Hasil =", hasil_3010)

# Assignment pembagian, pembagian bulat, dan sisa bagi
if angka2_3010 !=0:
    hasil_3010= angka1_3010
    hasil_3010 /= angka2_3010
    print("\nAssignment pembagian (/=)")
    print("Hasil =", hasil_3010)
    # Operator tambahan
    hasil_3010 = angka1_3010
    hasil_3010 //= angka2_3010
    print("\nAssignment pembagian bulat(//=)")
    print("Hasil =", hasil_3010)
    hasil_3010 = angka1_3010
    hasil_3010 %= angka2_3010
    print("\nAssignment sisa bagi (%=)")
    print("Hasil =", hasil_3010)
else:
    print("\nPembagian tidak dapat dilakukan")
    print("Angka kedua tidak boleh bernilai 0.")

# Operator tambahan: assignment perpangkatan
hasil_3010 = angka1_3010
hasil_3010 **= angka2_3010
print("\nAssignment perpangkatan (**=)")
print("Hasil =", hasil_3010)

# %% [markdown]
# Penjelasan program assignment di atas:
#
# Program menugaskan kembali nilai `hasil_3010` menggunakan assignment kombo seperti `+=`, `-=`, `*=`, `/=`, `//=`, `%=`, dan `**=`. Variabel penampung hasil harus selalu diinisialisasi atau disegarkan (refresh) setiap masuk baris perintah yang baru sehingga kalkulasi penambahan maupun perpangkatannya valid mengacu pada nilai orisinal dari variabel `angka1_3010`.

# %% [markdown]
# ### 2.2.3 Program Bitwise "bitwise_2611533010"

# %%
# Buat file dengan nama bitwise_2611533010.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_3010
# Program ini menggunakan fungsi input()

print("\n=============================")
print("3. OPERATOR BITWISE")
print("=============================")

angka1_3010 = int(input("Masukkan angka bitwise-1: "))
angka2_3010 = int(input("Masukkan angka bitwise-2: "))

print("\nAngka dalam bentuk desimal dan biner")
print("angka1 =", angka1_3010, "| biner =", bin(angka1_3010))
print("angka2 =", angka2_3010, "| biner =", bin(angka2_3010))

# Bitwise AND
hasil_3010 = angka1_3010 & angka2_3010
print("\nBitwise AND (&)")
print(angka1_3010, "&", angka2_3010, "=", hasil_3010)
print("Biner hasil =", bin(hasil_3010))
print("Biner hasil (8 bit) =", format(hasil_3010, "08b"))

# Bitwise OR
hasil_3010 = angka1_3010 | angka2_3010
print("\nBitwise OR (|)")
print(angka1_3010, "|", angka2_3010, "=", hasil_3010)
print("Biner hasil =", bin(hasil_3010))
print("Biner hasil (8 bit) =", format(hasil_3010, "08b"))

# Bitwise XOR
hasil_3010 = angka1_3010 ^ angka2_3010
print("\nBitwise XOR (^)")
print(angka1_3010, "^", angka2_3010, "=", hasil_3010)
print("Biner hasil =", bin(hasil_3010))
print("Biner hasil (8 bit) =", format(hasil_3010, "08b"))

# Bitwise NOT
hasil_3010 = ~angka1_3010
print("\nBitwise NOT (~)")
print("~", angka1_3010, "=", hasil_3010)
print("Biner hasil =", bin(hasil_3010))
print("Biner hasil (8 bit) =", format(hasil_3010, "08b"))

# Bitwise geser kiri
jumlah_geser_3010 = int(input("\nMasukkan jumlah pergeseran bit: "))

hasil_3010 = angka1_3010 << jumlah_geser_3010
print("\nBitwise geser kiri (<<)")
print(angka1_3010, "<<", jumlah_geser_3010, "=", hasil_3010)
print("Biner hasil =", bin(hasil_3010))
print("Biner hasil (8 bit) =", format(hasil_3010, "08b"))

# Bitwise geser kanan
hasil_3010 = angka1_3010 >> jumlah_geser_3010
print("\nBitwise geser kanan (>>)")
print(angka1_3010, ">>", jumlah_geser_3010, "=", hasil_3010)
print("Biner hasil =", bin(hasil_3010))
print("Biner hasil (8 bit) =", format(hasil_3010, "08b"))

# %% [markdown]
# Penjelasan program bitwise di atas:
#
# Program ini mengeksekusi operasi logika dasar berbasis bit seperti `AND`, `OR`, `XOR`, hingga invers `NOT` di mana setiap perhitungannya dikonversikan ke dalam format bilangan berbasis dua (biner) menggunakan instruksi `bin()` serta mencetak format kustom 8-bit `08b`. Pengguna juga diizinkan menyesuaikan pergeseran rentang bit secara bebas dengan input yang ditampung variabel `jumlah_geser_3010`.

# %% [markdown]
# ### 2.2.4 Program Lainnya "lainnya_2611533010"

# %%
# Buat file dengan nama lainnya_2611533010.py
# Nama variabel ditambah 4 digit terakhir contoh: angka1_3010
# Program ini menggunakan fungsi input()
# Program operator keanggotaan dan identitas

print("=================================")
print("1, OPERATOR KEANGGOTAAN")
print("=================================")

# Input beberapa data yang dipisahkan dengan koma
input_data_3010 = input("Masukkan beberapa angka, pisahkan dengan koma: ")

# Mengubah input menjadi list integer
data_3010 = [int(angka.strip()) for angka in input_data_3010.split(",")]

nilai_dicari_3010 = int(input("Masukkan angka yang ingin dicari: "))

# Operator in
hasil_3010 = nilai_dicari_3010 in data_3010
print ("\nOperator keanggotaan IN")
print(nilai_dicari_3010, "in", data_3010, "=", hasil_3010)

# Operator not in
hasil_3010 = nilai_dicari_3010 not in data_3010
print ("\nOperator keanggotaan NOT IN")
print(nilai_dicari_3010, "not in", data_3010, "=", hasil_3010)


print("\n============================")
print("2. OPERATOR IDENTITAS")
print("============================")

# objek1 menggunakan list dari input pengguna
objek1_3010 = data_3010

# objek2 merujuk pada objek yang sama dengan objek 1
objek2_3010 = objek1_3010

# objek2 memiliki isi sama, tetapi merupakan objek baru
objek3_3010 = data_3010.copy()

print("objek1 =", objek1_3010)
print("objek2 =", objek2_3010)
print("objek3 =", objek3_3010)

# Operator is
hasil_3010 = objek1_3010 is objek2_3010
print("\nOperator identitas IS")
print("objek1 is objek2 =", hasil_3010)

# Operator is not
hasil_3010 = objek1_3010 is not objek3_3010
print("\nOperator identitas IS NOT")
print("objek1 is not objek3 =", hasil_3010)

# Membandingkan identitas dan nilai
print("\nPerbandingan identitas dan nilai")
print("objek1 is objek 3 =", objek1_3010 is objek3_3010)
print("objek1 == objek3 =", objek1_3010 == objek3_3010)

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/input.png" width="400"><br>
# <em>Gambar 2.1 : Output Program Input</em>
# </div>
#
# **Penjelasan :**
# Program mendemonstrasikan pemeriksan keanggotaan dengan mengecek apakah inputan tersimpan di dalam list (`in` dan `not in`) setelah string angka dilakukan metode pemisahan koma `.split(",")`. Pada tahapan kedua, program memperlihatkan perbedaan antara menginisialisasi rujukan ke objek yang sama `objek2_3010 = objek1_3010` dengan pembentukan salinan mandiri `data_3010.copy()`. Hasil `is` dan `is not` merepresentasikan perbandingan lokasi memori, bukan sekadar membandingkan kesetaraan nilai biasa.

# %% [markdown]
# ### 2.2.5 Program Logika "logika_2611533010"

# %%
# Buat file dengan nama logika_2611533010.py
# Nama variabel ditambah 4 digit NIM terakhir contoh: a1_3010
# Program ini menggunakan fungsi input()
# Program operator logika dalam Python

# memasukkan nilai boolean
# Input tidak peka terhadap huruf besar dan kecil
a1_3010 = input("Input nilai boolean-1 (true/false): ").strip().lower() == "true"
a2_3010 = input("Input nilai boolean-2 (true/false): ").strip().lower() == "true"

print("\nA1 =", a1_3010)
print("A2 =", a2_3010)

# Konjungsi: bernilai True jika keduanya True
hasil_3010 = a1_3010 and a2_3010
print("\nKonjungsi (AND)")
print("A1 and A2 =", hasil_3010)

# Disjungsi: bernilai True jika salah satunya True
hasil_3010 = a1_3010 or a2_3010
print("\nDisjungsi (OR)")
print("A1 or A2 =", hasil_3010)

# Negasi A1: membalik nilai A1
hasil_3010 = not a1_3010
print("\nNegasi A1 (NOT)")
print("not A1 =", hasil_3010)

# Negasi A2: membalik nilai A2
hasil_3010 = not a2_3010
print("\nNegasi A2 (NOT)")
print("not A2 =", hasil_3010)

# XOR: bernilai True jika kedua nilai berbeda
hasil_3010 = a1_3010 != a2_3010
print("\nDisjungsi Eksklusif (XOR)")
print("A1 XOR A2 =", hasil_3010)

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/konstanta.png" width="400"><br>
# <em>Gambar 2.2 : Output Program Konstanta</em>
# </div>
#
# **Penjelasan :**
# Program membaca kondisi masukan berbasis huruf namun disanitasi sehingga bersifat absolut tidak case-sensitive melalui perpaduan instuksi pembersihan spasi `.strip()` dan `.lower()`. Nilai akhir akan diproses menggunakan logika konjungsi (`and`), disjungsi fleksibel (`or`), dan operan pembalikan arah (`not`) dengan hasil output boolean sejati.

# %% [markdown]
# ### 2.2.6 Program Perbandingan "perbandingan_2611533010"

# %%
# Buat file dengan nama perbandingan_2611533010.py
# Nama variabel ditambah 4 digit NIM terakhir contoh: angka1_3010
# Program ini menggunakan fungsi input()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
# Program operator perbandingan dalam Python

angka1_3010 = int(input("Input angka-1: "))
angka2_3010 = int(input("Input angka-2: "))

# Lebih besar dari
hasil_3010 = angka1_3010 > angka2_3010
print("\nOperator lebih besar dari")
print("angka1 > angka2 =", hasil_3010)

# Lebih kecil dari
hasil_3010 = angka1_3010 < angka2_3010
print("\nOperator lebih kecil dari")
print("angka1 < angka2 =", hasil_3010)

# Lebih besar dari atau sama dengan
hasil_3010 = angka1_3010 >= angka2_3010
print("\nOperator lebih besar dari atau sama dengan")
print("angka1 >= angka2 =", hasil_3010)

# Lebih kecil dari atau sama dengan
hasil_3010 = angka1_3010 <= angka2_3010
print("\nOperator lebih kecil dari atau sama dengan")
print("angka1 <= angka2 =", hasil_3010)

# Sama dengan
hasil_3010 = angka1_3010 == angka2_3010
print("\nOperator sama dengan")
print("angka1 == angka2 =", hasil_3010)

# Tidak sama dengan
hasil_3010 = angka1_3010 != angka2_3010
print("\nOperator tidak sama dengan")
print("angka1 != angka2 =", hasil_3010)

# Tambahan: perbandingan berantai dalam Python
hasil_3010 = 0 < angka1_3010 <100
print("\nPerbandingan berantai")
print("0 < angka1 < 100 =", hasil_3010)

hasil_3010 = 0 < angka2_3010 < 100
print("0 < angka2 < 100 =", hasil_3010)

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/konstanta.png" width="400"><br>
# <em>Gambar 2.2 : Output Program Konstanta</em>
# </div>
#
# **Penjelasan :**
# Selain melakukan uji parameter yang bersifat dasar seperti mendeteksi bilangan terbesar, terkecil, tidak sama dengan `!=`, dan persis sama `==`. Program ini juga menyematkan validasi berantai layaknya batasan rentang pada ilmu matematika konvensional `0 < x < 100` untuk membuktikan fungsionalitas sintaks di dalam Python sangat dinamis dan luwes dibaca.

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :**
# Studi Kasus: Sistem Simulasi Transaksi dan Validasi Akses Toko
# Anda diminta untuk membuat sebuah program kasir sederhana yang digunakan untuk menghitung total transaksi pelanggan sekaligus melakukan pemeriksaan terhadap status pelanggan dan hak akses terhadap promo tertentu. Program menerima data transaksi dan informasi pelanggan, kemudian menggunakan berbagai jenis operator Python untuk menentukan total pembayaran, status diskon, kelayakan promo, serta hak akses pelanggan. Seluruh proses harus dibuat dalam satu alur program yang utuh.

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "Tugas3_2611531012.py"

# %%
# Tugas3_2611533010.py
# Sistem Simulasi Transaksi dan Validasi Akses Toko

print("=== SISTEM TRANSAKSI TOKO ===\n")

# Input Data Pelanggan
nama_3010 = input("Masukkan Nama Pelanggan : ")
status_3010 = input("Masukkan Status Pelanggan (member/nonmember) : ").lower()
total_belanja_3010 = int(input("Masukkan Total Belanja : "))
jumlah_barang_3010 = int(input("Masukkan Jumlah Barang : "))
kode_promo_input_3010 = input("Masukkan Kode Promo : ")

# Operator Keanggotaan
daftar_promo_3010 = ["HEMAT10", "HEMAT20", "GRATISONGKIR"]
promo_tersedia_3010 = kode_promo_input_3010 in daftar_promo_3010
promo_tidak_valid_3010 = kode_promo_input_3010 not in daftar_promo_3010

# Operator Perbandingan & Logika
syarat_belanja_3010 = total_belanja_3010 >= 200000
syarat_barang_3010 = jumlah_barang_3010 >= 3
is_member_3010 = status_3010 == "member"

# Logika Penggabungan (and)
dapat_diskon_3010 = is_member_3010 and syarat_belanja_3010
dapat_promo_3010 = promo_tersedia_3010 and syarat_barang_3010

# Operator Identitas
promo_ref_3010 = daftar_promo_3010
promo_copy_3010 = daftar_promo_3010.copy()

# Membuktikan identitas objek
is_same_object_3010 = promo_ref_3010 is daftar_promo_3010
is_diff_object_3010 = promo_copy_3010 is not daftar_promo_3010

# Operator Aritmatika & Penugasan
besaran_diskon_3010 = 0
if dapat_diskon_3010:
    besaran_diskon_3010 = total_belanja_3010 * 10 // 100 # Diskon 10%

# Assignment
total_pembayaran_3010 = total_belanja_3010
total_pembayaran_3010 -= besaran_diskon_3010 # Augmented assignment pengurangan

# Aritmatika lanjutan
rata_rata_harga_3010 = total_belanja_3010 // jumlah_barang_3010
sisa_bagi_3010 = total_belanja_3010 % jumlah_barang_3010

# 6. Operator Bitwise
# 0001 (1) = Member | 0010 (2) = Belanja >= 200k | 0100 (4) = Barang >= 3 | 1000 (8) = Promo
status_code_3010 = 0
if is_member_3010: status_code_3010 |= 1
if syarat_belanja_3010: status_code_3010 |= 2
if syarat_barang_3010: status_code_3010 |= 4
if promo_tersedia_3010: status_code_3010 |= 8

cek_member_bitwise_3010 = status_code_3010 & 1
cek_promo_bitwise_3010 = status_code_3010 & 8

# Perbandingan Status (XOR) dan Shift
kode_referensi_3010 = 11 # 1011 Biner
hasil_xor_3010 = status_code_3010 ^ kode_referensi_3010
shift_kiri_3010 = status_code_3010 << 1

# === OUTPUT PROGRAM ===
print("\n=== DATA TRANSAKSI ===")
print(f"Nama Pelanggan       : {nama_3010}")
print(f"Status Pelanggan     : {status_3010}")
print(f"Total Belanja        : Rp{total_belanja_3010}")
print(f"Jumlah Barang        : {jumlah_barang_3010}")
print(f"Kode Promo           : {kode_promo_input_3010}")

print("\n=== HASIL VALIDASI ===")
print(f"Belanja >= Rp200000  : {syarat_belanja_3010}")
print(f"Jumlah Barang >= 3   : {syarat_barang_3010}")
print(f"Status Member        : {is_member_3010}")
print(f"Kode Promo Tersedia  : {promo_tersedia_3010}")
print(f"Mendapatkan Diskon   : {dapat_diskon_3010}")
print(f"Mendapatkan Promo    : {dapat_promo_3010}")

print("\n=== HASIL PERHITUNGAN ===")
print(f"Diskon               : Rp{besaran_diskon_3010}")
print(f"Total Pembayaran     : Rp{total_pembayaran_3010}")
print(f"Rata-rata Harga Barang : Rp{rata_rata_harga_3010}")
print(f"Sisa Bagi (Modulus)  : Rp{sisa_bagi_3010}")

print("\n=== HAK AKSES PELANGGAN ===")
print(f"Kode Hak Akses       : {format(status_code_3010, '04b')}")
print(f"Member Access        : {bool(cek_member_bitwise_3010)}")
print(f"Promo Access         : {bool(cek_promo_bitwise_3010)}")

print("\n=== OPERASI BITWISE ===")
print("=== Kode Status Transaksi ===")
print(f"Kode Biner   : {format(status_code_3010, '04b')}")
print(f"Kode Desimal : {status_code_3010}")

print("\n=== Pemeriksaan Status ===")
print("Cek Member")
print(f"{format(status_code_3010, '04b')} & 0001")
print(f"Hasil Biner   : {format(cek_member_bitwise_3010, '04b')}")
print(f"Hasil Desimal : {cek_member_bitwise_3010}")

print("\nCek Promo")
print(f"{format(status_code_3010, '04b')} & 1000")
print(f"Hasil Biner   : {format(cek_promo_bitwise_3010, '04b')}")
print(f"Hasil Desimal : {cek_promo_bitwise_3010}")

print("\n=== Perbandingan Status ===")
print(f"Kode Transaksi : {format(status_code_3010, '04b')}")
print(f"Kode Referensi : {format(kode_referensi_3010, '04b')}")
print(f"{format(status_code_3010, '04b')} ^ {format(kode_referensi_3010, '04b')}")
print(f"Hasil Biner   : {format(hasil_xor_3010, '04b')}")
print(f"Hasil Desimal : {hasil_xor_3010}")

print("\n=== Shift ===")
print(f"{format(status_code_3010, '04b')} << 1")
print(f"Hasil Biner   : {format(shift_kiri_3010, '05b')}")
print(f"Hasil Desimal : {shift_kiri_3010}")
print("\n=== SELESAI ===")

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/outputtugas2.png" width="400"><br>
# <em>Gambar 2.3 : Output Tugas Praktikum</em>
# </div>
#
# **Penjelasan :**
#
# **Output :**
# *(Hasil eksekusi program (I/O) tercetak otomatis di atas sel ini menyesuaikan input saat di-run)*
#
# **Penjelasan :**
# Program simulasi transaksi toko di atas sangat kompleks karena merepresentasikan integrasi seluruh penggabungan sintaks logika Python pada modul yang dipelajari. Algoritma program dirancang efisien memanfaatkan operator keanggotaan (`in`) untuk memverifikasi keabsahan masukan dari string kupon pengguna di dalam list. Kode juga memanfaatkan kombo operator logika dan perbandingan secara simultan untuk mendeteksi variabel syarat seperti besaran nilai total belanja dan konfirmasi member. Pada implementasi puncaknya, status-status pelanggan ini tidak dihitung biasa melainkan diterjemahkan menggunakan operator bitwise (`|`, `&`, `^`, `<<`), di mana masing-masing kriteria diwakili sebagai perhitungan level bit tersendiri, layaknya sistem validasi persetujuan matriks.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa bahasa pemrograman Python menyediakan serangkaian operator struktural yang tergolong lengkap dan menyeluruh, mulai dari operator komputasi dasar (aritmatika), penyaring (perbandingan, identitas, keanggotaan), pengatur kontrol flow (logika, penugasan), hingga komputasi kalkulasi pada bit-level memori komputer terbawah (bitwise). Dalam konteks implementasi di lingkungan nyata, penggabungan operator ini dimanfaatkan penuh untuk mengelola seleksi kondisi agar dapat memvalidasi data kompleks layaknya membangun sistem keamanan dan integrasi pembayaran toko otomatis.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] A. Kadir, Dasar Pemrograman Python 3, Yogyakarta: Penerbit Andi, 2018
#
# [2] I. G. N. Suryantara, Python: Bahasa Pemrograman Era Digital, Jakarta: PT Elex Media Komputindo, 2024
#
# [3] S. Junaidi dan M. Devegi, Algoritma dan Pemrograman dengan Python, Jambi: PT. Sonpedia Publishing Indonesia, 2023
